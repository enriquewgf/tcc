# %%
# Dependencias

# !pip install yfinance
# !pip install EMD-signal==1.0.0

# %%
# imports e definições

from PyEMD import CEEMDAN
from datetime import timedelta, datetime
import pandas as pd
from pandas_datareader import data as pdr
import numpy as np
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler

# %%
# date_index = stocks[stock].index

def set_ceemdan(ticker, imf, data, date_index, connection):
  features_in_order = ['Open', 'High', 'Low', 'Volume', 'Adj Close']
  table_name = ticker + '_' + imf
  pd_dataset = pd.DataFrame(data, columns=features_in_order)
  pd_dataset.set_index(date_index, inplace=True)
  pd_dataset.to_sql(table_name, con=connection, if_exists='replace')
  print(f'{table_name} stored in the database!')
  
  return table_name

def get_ceemdan(ticker, imf, connection):
  table_name = ticker + '_' + imf
  query = 'SELECT * from ' + table_name

  result = connection.execute(query)
  df = pd.DataFrame(result.fetchall())
  df.columns = result.keys()
  df.set_index('Date', inplace=True)

  return df

# %%
# Giving access to my google drive

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
 # This creates a symbolic link so that now the path to the database in GoogleDrive is equal to /mydb

# !ln -s /content/gdrive/Shareddrives/TCC/Implementação/Capitulo3_Treinamento/db /mydb

# %%
# !ls /mydb
# Out:
# 13_14_15.db  14_15_16.db  15_16_17.db  Close  db  empty.db

# %%
from sqlalchemy import create_engine
my_conn = create_engine("sqlite:////mydb/13_14_15.db")

# %%
# Database connection (with all IMFs)

# for now it's a webscrapping and CEEMDAN decomposition

features_in_order = ['Open', 'High', 'Low', 'Volume', 'Adj Close'] # target feature must be the last one here
target_feature = 'Adj Close'

stocks_list = ['ABEV3.SA', 'BBAS3.SA', 'BBDC3.SA', 'BBSE3.SA', 'BRAP4.SA', 'BRFS3.SA', 'BRKM5.SA', 'BRML3.SA', 'BRPR3.SA', 'BRSR6.SA', 'AMER3.SA', 'CCRO3.SA', 'CESP6.SA', 'CIEL3.SA', 'CMIG4.SA', 'CPFE3.SA', 'CPLE6.SA', 'CSAN3.SA', 'CSNA3.SA', 'CYRE3.SA', 'DXCO3.SA', 'ECOR3.SA', 'ELET3.SA', 'EMBR3.SA', 'ENBR3.SA', 'EQTL3.SA', 'YDUQ3.SA', 'EVEN3.SA', 'EZTC3.SA', 'FIBR3.SA', 'GFSA3.SA', 'GGBR4.SA', 'GOAU4.SA', 'GOLL4.SA', 'HGTX3.SA', 'HYPE3.SA', 'IGTA3.SA', 'ITSA4.SA', 'ITUB4.SA', 'JBSS3.SA', 'KLBN11.SA', 'COGN3.SA', 'LAME4.SA', 'LIGT3.SA', 'LREN3.SA', 'MDIA3.SA', 'MGLU3.SA', 'MILS3.SA', 'MMXM3.SA', 'MRFG3.SA', 'MRVE3.SA', 'MULT3.SA', 'ODPV3.SA', 'OIBR3.SA', 'PCAR3.SA', 'PDGR3.SA', 'PETR3.SA', 'POMO4.SA', 'PSSA3.SA', 'ENAT3.SA', 'QUAL3.SA', 'RADL3.SA', 'RAPT4.SA', 'RENT3.SA', 'RSID3.SA', 'SANB3.SA', 'SBSP3.SA', 'SULA11.SA', 'TAEE11.SA', 'TIMS3.SA', 'TOTS3.SA', 'UGPA3.SA', 'USIM5.SA', 'VALE3.SA', 'VIVT3.SA', 'VLID3.SA', 'VVAR11.SA', 'WEGE3.SA' ]

def get_stock_infos(stock, start_date, end_date):
  yf.pdr_override()
  data = pdr.get_data_yahoo(stock, start_date, end_date).dropna()[features_in_order]
  return data

start_datetime = datetime(year=2013, month=1, day=1)
end_datetime = datetime(year=2015, month=12, day=31)

stocks = {}
for stock in stocks_list:
  stocks[stock.replace('.SA', '')] = get_stock_infos(stock, start_datetime, end_datetime)

ceemdan = CEEMDAN()   # They add noise in the paper.. should you add it too?
decomposed_data = {}
decomposed_stock_features_series = {}
scalers = {}
for stock in stocks:
  # loop das acoes
  print(f'{stock} Decompondo...')
  stock_dataframe = stocks[stock]
  decomposed_stock_features_series[stock] = {}
  scalers[stock] = {}
  for column in stock_dataframe.columns:
    # loop das features
    scaler = MinMaxScaler()
    decomposed_stock_features_series[stock][column] = {}
    #series = stock_dataframe[column].values                                          # (247,) 1D array
    series = stock_dataframe[column].values.reshape(-1,1)                             # (247, 1) 2D array
    scaler.fit(series)                                                                # Compute the minimum and maximum to be used for later scaling.
    scalers[stock][column] = scaler                                                   # MinMaxScaler(copy=True, feature_range=(0, 1))
    stock_feature_time_series = np.frombuffer(scaler.transform(series))               # scaler.transform(series) is the 2D normalized series and frombuffer makes it 1D
    stock_feature_time_series_imfs = ceemdan(stock_feature_time_series, max_imf=10)   # (5, 247) 247 is the number of values and 5 the number of imfs (which varies depending on the series)
    for i, imf_series in enumerate(stock_feature_time_series_imfs):
      # loop das IMF
      if i < len(stock_feature_time_series_imfs):                                     # If (5, 247), len is 247
        decomposed_stock_features_series[stock][column][f'IMF{i+1}'] = imf_series
      else:
        decomposed_stock_features_series[stock][column][f'Rsd'] = imf_series  


target_feature_max_imf_level = {}
series = {}

for stock in decomposed_stock_features_series:
  series[stock] = {}
  for feature in decomposed_stock_features_series[stock]:
    imfs = pd.DataFrame.from_dict(decomposed_stock_features_series[stock][feature])
    for imf in imfs:                                        # imf = 'IMF1' ou 'IMF2'
      if imf not in series[stock]:
        series[stock][imf] = []                             # {'PETR4': {'IMF1': [], 'IMF2': [], 'IMF3': [], 'IMF4': [], 'IMF5': [], 'IMF6': [], 'IMF7': []}}
      _series = imfs[imf].values                            # (247,)
      _series = _series.reshape((len(_series), 1))          # (247, 1)
      series[stock][imf] += [_series]                       # {'PETR4': {'IMF1': [imf_values_2D_array], 'IMF2': [], ...}} one 2D_array for each feature
      if feature == target_feature:
        target_feature_max_imf_level[stock] = imf        

series_cut = {}
for stock in series:
  if stock not in series_cut:
    series_cut[stock] = {}
  for imf_level_string in series[stock]:
    imf_level_int = int(imf_level_string[3:])
    if imf_level_int > int(target_feature_max_imf_level[stock][3:]):
      continue
    else:
      series_cut[stock][imf_level_string] = series[stock][imf_level_string].copy()

series = series_cut
dataset = {}

for stock in series:
  dataset[stock] = {}
  for imf_level in series[stock]:
    dataset[stock][imf_level] = np.hstack( tuple(series[stock][imf_level]) )
    if dataset[stock][imf_level].shape[1] == 5:     # Some IMFs don't have 5 columns, for some reason
      set_ceemdan(stock, imf_level, dataset[stock][imf_level], stocks[stock].index, my_conn)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ABEV3 Decompondo...
# BBAS3 Decompondo...
# BBDC3 Decompondo...
# BBSE3 Decompondo...
# BRAP4 Decompondo...
# BRFS3 Decompondo...
# BRKM5 Decompondo...
# BRML3 Decompondo...
# BRPR3 Decompondo...
# BRSR6 Decompondo...
# AMER3 Decompondo...
# CCRO3 Decompondo...
# CESP6 Decompondo...
# CIEL3 Decompondo...
# CMIG4 Decompondo...
# CPFE3 Decompondo...
# CPLE6 Decompondo...
# CSAN3 Decompondo...
# CSNA3 Decompondo...
# CYRE3 Decompondo...
# DXCO3 Decompondo...
# ECOR3 Decompondo...
# ELET3 Decompondo...
# EMBR3 Decompondo...
# ENBR3 Decompondo...
# EQTL3 Decompondo...
# YDUQ3 Decompondo...
# EVEN3 Decompondo...
# EZTC3 Decompondo...
# FIBR3 Decompondo...
# GFSA3 Decompondo...
# GGBR4 Decompondo...
# GOAU4 Decompondo...
# GOLL4 Decompondo...
# HGTX3 Decompondo...
# /usr/local/lib/python3.7/dist-packages/PyEMD/CEEMDAN.py:183: RuntimeWarning: invalid value encountered in true_divide
#   S = S/scale_s
# /usr/local/lib/python3.7/dist-packages/PyEMD/CEEMDAN.py:183: RuntimeWarning: invalid value encountered in true_divide
#   S = S/scale_s
# /usr/local/lib/python3.7/dist-packages/PyEMD/CEEMDAN.py:183: RuntimeWarning: invalid value encountered in true_divide
#   S = S/scale_s
# /usr/local/lib/python3.7/dist-packages/PyEMD/CEEMDAN.py:183: RuntimeWarning: invalid value encountered in true_divide
#   S = S/scale_s
# HYPE3 Decompondo...
# IGTA3 Decompondo...
# ITSA4 Decompondo...
# ITUB4 Decompondo...
# JBSS3 Decompondo...
# KLBN11 Decompondo...
# COGN3 Decompondo...
# LAME4 Decompondo...
# LIGT3 Decompondo...
# LREN3 Decompondo...
# MDIA3 Decompondo...
# MGLU3 Decompondo...
# MILS3 Decompondo...
# MMXM3 Decompondo...
# MRFG3 Decompondo...
# MRVE3 Decompondo...
# MULT3 Decompondo...
# ODPV3 Decompondo...
# OIBR3 Decompondo...
# PCAR3 Decompondo...
# PDGR3 Decompondo...
# PETR3 Decompondo...
# POMO4 Decompondo...
# PSSA3 Decompondo...
# ENAT3 Decompondo...
# QUAL3 Decompondo...
# RADL3 Decompondo...
# RAPT4 Decompondo...
# RENT3 Decompondo...
# RSID3 Decompondo...
# SANB3 Decompondo...
# SBSP3 Decompondo...
# SULA11 Decompondo...
# TAEE11 Decompondo...
# TIMS3 Decompondo...
# TOTS3 Decompondo...
# UGPA3 Decompondo...
# USIM5 Decompondo...
# VALE3 Decompondo...
# VIVT3 Decompondo...
# VLID3 Decompondo...
# VVAR11 Decompondo...
# WEGE3 Decompondo...
# ABEV3_IMF1 stored in the database!
# ABEV3_IMF2 stored in the database!
# ABEV3_IMF3 stored in the database!
# ABEV3_IMF4 stored in the database!
# ABEV3_IMF5 stored in the database!
# ABEV3_IMF6 stored in the database!
# BBAS3_IMF1 stored in the database!
# BBAS3_IMF2 stored in the database!
# BBAS3_IMF3 stored in the database!
# BBAS3_IMF4 stored in the database!
# BBAS3_IMF5 stored in the database!
# BBAS3_IMF6 stored in the database!
# BBDC3_IMF1 stored in the database!
# BBDC3_IMF2 stored in the database!
# BBDC3_IMF3 stored in the database!
# BBDC3_IMF4 stored in the database!
# BBDC3_IMF5 stored in the database!
# BBDC3_IMF6 stored in the database!
# BBSE3_IMF1 stored in the database!
# BBSE3_IMF2 stored in the database!
# BBSE3_IMF3 stored in the database!
# BBSE3_IMF4 stored in the database!
# BBSE3_IMF5 stored in the database!
# BBSE3_IMF6 stored in the database!
# BRAP4_IMF1 stored in the database!
# BRAP4_IMF2 stored in the database!
# BRAP4_IMF3 stored in the database!
# BRAP4_IMF4 stored in the database!
# BRAP4_IMF5 stored in the database!
# BRAP4_IMF6 stored in the database!
# BRFS3_IMF1 stored in the database!
# BRFS3_IMF2 stored in the database!
# BRFS3_IMF3 stored in the database!
# BRFS3_IMF4 stored in the database!
# BRFS3_IMF5 stored in the database!
# BRFS3_IMF6 stored in the database!
# BRKM5_IMF1 stored in the database!
# BRKM5_IMF2 stored in the database!
# BRKM5_IMF3 stored in the database!
# BRKM5_IMF4 stored in the database!
# BRKM5_IMF5 stored in the database!
# BRKM5_IMF6 stored in the database!
# BRKM5_IMF7 stored in the database!
# BRML3_IMF1 stored in the database!
# BRML3_IMF2 stored in the database!
# BRML3_IMF3 stored in the database!
# BRML3_IMF4 stored in the database!
# BRML3_IMF5 stored in the database!
# BRML3_IMF6 stored in the database!
# BRML3_IMF7 stored in the database!
# BRPR3_IMF1 stored in the database!
# BRPR3_IMF2 stored in the database!
# BRPR3_IMF3 stored in the database!
# BRPR3_IMF4 stored in the database!
# BRPR3_IMF5 stored in the database!
# BRPR3_IMF6 stored in the database!
# BRPR3_IMF7 stored in the database!
# BRSR6_IMF1 stored in the database!
# BRSR6_IMF2 stored in the database!
# BRSR6_IMF3 stored in the database!
# BRSR6_IMF4 stored in the database!
# BRSR6_IMF5 stored in the database!
# BRSR6_IMF6 stored in the database!
# BRSR6_IMF7 stored in the database!
# AMER3_IMF1 stored in the database!
# AMER3_IMF2 stored in the database!
# AMER3_IMF3 stored in the database!
# AMER3_IMF4 stored in the database!
# AMER3_IMF5 stored in the database!
# AMER3_IMF6 stored in the database!
# AMER3_IMF7 stored in the database!
# CCRO3_IMF1 stored in the database!
# CCRO3_IMF2 stored in the database!
# CCRO3_IMF3 stored in the database!
# CCRO3_IMF4 stored in the database!
# CCRO3_IMF5 stored in the database!
# CCRO3_IMF6 stored in the database!
# CCRO3_IMF7 stored in the database!
# CESP6_IMF1 stored in the database!
# CESP6_IMF2 stored in the database!
# CESP6_IMF3 stored in the database!
# CESP6_IMF4 stored in the database!
# CESP6_IMF5 stored in the database!
# CESP6_IMF6 stored in the database!
# CIEL3_IMF1 stored in the database!
# CIEL3_IMF2 stored in the database!
# CIEL3_IMF3 stored in the database!
# CIEL3_IMF4 stored in the database!
# CIEL3_IMF5 stored in the database!
# CIEL3_IMF6 stored in the database!
# CMIG4_IMF1 stored in the database!
# CMIG4_IMF2 stored in the database!
# CMIG4_IMF3 stored in the database!
# CMIG4_IMF4 stored in the database!
# CMIG4_IMF5 stored in the database!
# CMIG4_IMF6 stored in the database!
# CPFE3_IMF1 stored in the database!
# CPFE3_IMF2 stored in the database!
# CPFE3_IMF3 stored in the database!
# CPFE3_IMF4 stored in the database!
# CPFE3_IMF5 stored in the database!
# CPFE3_IMF6 stored in the database!
# CPFE3_IMF7 stored in the database!
# CPLE6_IMF1 stored in the database!
# CPLE6_IMF2 stored in the database!
# CPLE6_IMF3 stored in the database!
# CPLE6_IMF4 stored in the database!
# CPLE6_IMF5 stored in the database!
# CPLE6_IMF6 stored in the database!
# CPLE6_IMF7 stored in the database!
# CSAN3_IMF1 stored in the database!
# CSAN3_IMF2 stored in the database!
# CSAN3_IMF3 stored in the database!
# CSAN3_IMF4 stored in the database!
# CSAN3_IMF5 stored in the database!
# CSAN3_IMF6 stored in the database!
# CSNA3_IMF1 stored in the database!
# CSNA3_IMF2 stored in the database!
# CSNA3_IMF3 stored in the database!
# CSNA3_IMF4 stored in the database!
# CSNA3_IMF5 stored in the database!
# CSNA3_IMF6 stored in the database!
# CSNA3_IMF7 stored in the database!
# CYRE3_IMF1 stored in the database!
# CYRE3_IMF2 stored in the database!
# CYRE3_IMF3 stored in the database!
# CYRE3_IMF4 stored in the database!
# CYRE3_IMF5 stored in the database!
# CYRE3_IMF6 stored in the database!
# DXCO3_IMF1 stored in the database!
# DXCO3_IMF2 stored in the database!
# DXCO3_IMF3 stored in the database!
# DXCO3_IMF4 stored in the database!
# DXCO3_IMF5 stored in the database!
# DXCO3_IMF6 stored in the database!
# ECOR3_IMF1 stored in the database!
# ECOR3_IMF2 stored in the database!
# ECOR3_IMF3 stored in the database!
# ECOR3_IMF4 stored in the database!
# ECOR3_IMF5 stored in the database!
# ECOR3_IMF6 stored in the database!
# ELET3_IMF1 stored in the database!
# ELET3_IMF2 stored in the database!
# ELET3_IMF3 stored in the database!
# ELET3_IMF4 stored in the database!
# ELET3_IMF5 stored in the database!
# ELET3_IMF6 stored in the database!
# ELET3_IMF7 stored in the database!
# EMBR3_IMF1 stored in the database!
# EMBR3_IMF2 stored in the database!
# EMBR3_IMF3 stored in the database!
# EMBR3_IMF4 stored in the database!
# EMBR3_IMF5 stored in the database!
# EMBR3_IMF6 stored in the database!
# EMBR3_IMF7 stored in the database!
# ENBR3_IMF1 stored in the database!
# ENBR3_IMF2 stored in the database!
# ENBR3_IMF3 stored in the database!
# ENBR3_IMF4 stored in the database!
# ENBR3_IMF5 stored in the database!
# ENBR3_IMF6 stored in the database!
# ENBR3_IMF7 stored in the database!
# EQTL3_IMF1 stored in the database!
# EQTL3_IMF2 stored in the database!
# EQTL3_IMF3 stored in the database!
# EQTL3_IMF4 stored in the database!
# EQTL3_IMF5 stored in the database!
# EQTL3_IMF6 stored in the database!
# YDUQ3_IMF1 stored in the database!
# YDUQ3_IMF2 stored in the database!
# YDUQ3_IMF3 stored in the database!
# YDUQ3_IMF4 stored in the database!
# YDUQ3_IMF5 stored in the database!
# YDUQ3_IMF6 stored in the database!
# EVEN3_IMF1 stored in the database!
# EVEN3_IMF2 stored in the database!
# EVEN3_IMF3 stored in the database!
# EVEN3_IMF4 stored in the database!
# EVEN3_IMF5 stored in the database!
# EVEN3_IMF6 stored in the database!
# EZTC3_IMF1 stored in the database!
# EZTC3_IMF2 stored in the database!
# EZTC3_IMF3 stored in the database!
# EZTC3_IMF4 stored in the database!
# EZTC3_IMF5 stored in the database!
# EZTC3_IMF6 stored in the database!
# EZTC3_IMF7 stored in the database!
# FIBR3_IMF1 stored in the database!
# FIBR3_IMF2 stored in the database!
# FIBR3_IMF3 stored in the database!
# FIBR3_IMF4 stored in the database!
# FIBR3_IMF5 stored in the database!
# FIBR3_IMF6 stored in the database!
# GFSA3_IMF1 stored in the database!
# GFSA3_IMF2 stored in the database!
# GFSA3_IMF3 stored in the database!
# GFSA3_IMF4 stored in the database!
# GFSA3_IMF5 stored in the database!
# GFSA3_IMF6 stored in the database!
# GFSA3_IMF7 stored in the database!
# GGBR4_IMF1 stored in the database!
# GGBR4_IMF2 stored in the database!
# GGBR4_IMF3 stored in the database!
# GGBR4_IMF4 stored in the database!
# GGBR4_IMF5 stored in the database!
# GGBR4_IMF6 stored in the database!
# GOAU4_IMF1 stored in the database!
# GOAU4_IMF2 stored in the database!
# GOAU4_IMF3 stored in the database!
# GOAU4_IMF4 stored in the database!
# GOAU4_IMF5 stored in the database!
# GOAU4_IMF6 stored in the database!
# GOLL4_IMF1 stored in the database!
# GOLL4_IMF2 stored in the database!
# GOLL4_IMF3 stored in the database!
# GOLL4_IMF4 stored in the database!
# GOLL4_IMF5 stored in the database!
# GOLL4_IMF6 stored in the database!
# HGTX3_IMF1 stored in the database!
# HGTX3_IMF2 stored in the database!
# HGTX3_IMF3 stored in the database!
# HGTX3_IMF4 stored in the database!
# HGTX3_IMF5 stored in the database!
# HGTX3_IMF6 stored in the database!
# HYPE3_IMF1 stored in the database!
# HYPE3_IMF2 stored in the database!
# HYPE3_IMF3 stored in the database!
# HYPE3_IMF4 stored in the database!
# HYPE3_IMF5 stored in the database!
# HYPE3_IMF6 stored in the database!
# HYPE3_IMF7 stored in the database!
# IGTA3_IMF1 stored in the database!
# IGTA3_IMF2 stored in the database!
# IGTA3_IMF3 stored in the database!
# IGTA3_IMF4 stored in the database!
# IGTA3_IMF5 stored in the database!
# IGTA3_IMF6 stored in the database!
# IGTA3_IMF7 stored in the database!
# ITSA4_IMF1 stored in the database!
# ITSA4_IMF2 stored in the database!
# ITSA4_IMF3 stored in the database!
# ITSA4_IMF4 stored in the database!
# ITSA4_IMF5 stored in the database!
# ITSA4_IMF6 stored in the database!
# ITSA4_IMF7 stored in the database!
# ITUB4_IMF1 stored in the database!
# ITUB4_IMF2 stored in the database!
# ITUB4_IMF3 stored in the database!
# ITUB4_IMF4 stored in the database!
# ITUB4_IMF5 stored in the database!
# ITUB4_IMF6 stored in the database!
# ITUB4_IMF7 stored in the database!
# JBSS3_IMF1 stored in the database!
# JBSS3_IMF2 stored in the database!
# JBSS3_IMF3 stored in the database!
# JBSS3_IMF4 stored in the database!
# JBSS3_IMF5 stored in the database!
# JBSS3_IMF6 stored in the database!
# KLBN11_IMF1 stored in the database!
# KLBN11_IMF2 stored in the database!
# KLBN11_IMF3 stored in the database!
# KLBN11_IMF4 stored in the database!
# KLBN11_IMF5 stored in the database!
# KLBN11_IMF6 stored in the database!
# COGN3_IMF1 stored in the database!
# COGN3_IMF2 stored in the database!
# COGN3_IMF3 stored in the database!
# COGN3_IMF4 stored in the database!
# COGN3_IMF5 stored in the database!
# COGN3_IMF6 stored in the database!
# LAME4_IMF1 stored in the database!
# LAME4_IMF2 stored in the database!
# LAME4_IMF3 stored in the database!
# LAME4_IMF4 stored in the database!
# LAME4_IMF5 stored in the database!
# LAME4_IMF6 stored in the database!
# LIGT3_IMF1 stored in the database!
# LIGT3_IMF2 stored in the database!
# LIGT3_IMF3 stored in the database!
# LIGT3_IMF4 stored in the database!
# LIGT3_IMF5 stored in the database!
# LIGT3_IMF6 stored in the database!
# LIGT3_IMF7 stored in the database!
# LREN3_IMF1 stored in the database!
# LREN3_IMF2 stored in the database!
# LREN3_IMF3 stored in the database!
# LREN3_IMF4 stored in the database!
# LREN3_IMF5 stored in the database!
# LREN3_IMF6 stored in the database!
# MDIA3_IMF1 stored in the database!
# MDIA3_IMF2 stored in the database!
# MDIA3_IMF3 stored in the database!
# MDIA3_IMF4 stored in the database!
# MDIA3_IMF5 stored in the database!
# MDIA3_IMF6 stored in the database!
# MDIA3_IMF7 stored in the database!
# MGLU3_IMF1 stored in the database!
# MGLU3_IMF2 stored in the database!
# MGLU3_IMF3 stored in the database!
# MGLU3_IMF4 stored in the database!
# MGLU3_IMF5 stored in the database!
# MGLU3_IMF6 stored in the database!
# MILS3_IMF1 stored in the database!
# MILS3_IMF2 stored in the database!
# MILS3_IMF3 stored in the database!
# MILS3_IMF4 stored in the database!
# MILS3_IMF5 stored in the database!
# MILS3_IMF6 stored in the database!
# MMXM3_IMF1 stored in the database!
# MMXM3_IMF2 stored in the database!
# MMXM3_IMF3 stored in the database!
# MMXM3_IMF4 stored in the database!
# MMXM3_IMF5 stored in the database!
# MMXM3_IMF6 stored in the database!
# MRFG3_IMF1 stored in the database!
# MRFG3_IMF2 stored in the database!
# MRFG3_IMF3 stored in the database!
# MRFG3_IMF4 stored in the database!
# MRFG3_IMF5 stored in the database!
# MRFG3_IMF6 stored in the database!
# MRFG3_IMF7 stored in the database!
# MRVE3_IMF1 stored in the database!
# MRVE3_IMF2 stored in the database!
# MRVE3_IMF3 stored in the database!
# MRVE3_IMF4 stored in the database!
# MRVE3_IMF5 stored in the database!
# MRVE3_IMF6 stored in the database!
# MRVE3_IMF7 stored in the database!
# MULT3_IMF1 stored in the database!
# MULT3_IMF2 stored in the database!
# MULT3_IMF3 stored in the database!
# MULT3_IMF4 stored in the database!
# MULT3_IMF5 stored in the database!
# MULT3_IMF6 stored in the database!
# MULT3_IMF7 stored in the database!
# ODPV3_IMF1 stored in the database!
# ODPV3_IMF2 stored in the database!
# ODPV3_IMF3 stored in the database!
# ODPV3_IMF4 stored in the database!
# ODPV3_IMF5 stored in the database!
# ODPV3_IMF6 stored in the database!
# ODPV3_IMF7 stored in the database!
# OIBR3_IMF1 stored in the database!
# OIBR3_IMF2 stored in the database!
# OIBR3_IMF3 stored in the database!
# OIBR3_IMF4 stored in the database!
# OIBR3_IMF5 stored in the database!
# OIBR3_IMF6 stored in the database!
# OIBR3_IMF7 stored in the database!
# PCAR3_IMF1 stored in the database!
# PCAR3_IMF2 stored in the database!
# PCAR3_IMF3 stored in the database!
# PCAR3_IMF4 stored in the database!
# PCAR3_IMF5 stored in the database!
# PCAR3_IMF6 stored in the database!
# PCAR3_IMF7 stored in the database!
# PDGR3_IMF1 stored in the database!
# PDGR3_IMF2 stored in the database!
# PDGR3_IMF3 stored in the database!
# PDGR3_IMF4 stored in the database!
# PDGR3_IMF5 stored in the database!
# PDGR3_IMF6 stored in the database!
# PETR3_IMF1 stored in the database!
# PETR3_IMF2 stored in the database!
# PETR3_IMF3 stored in the database!
# PETR3_IMF4 stored in the database!
# PETR3_IMF5 stored in the database!
# PETR3_IMF6 stored in the database!
# PETR3_IMF7 stored in the database!
# POMO4_IMF1 stored in the database!
# POMO4_IMF2 stored in the database!
# POMO4_IMF3 stored in the database!
# POMO4_IMF4 stored in the database!
# POMO4_IMF5 stored in the database!
# POMO4_IMF6 stored in the database!
# PSSA3_IMF1 stored in the database!
# PSSA3_IMF2 stored in the database!
# PSSA3_IMF3 stored in the database!
# PSSA3_IMF4 stored in the database!
# PSSA3_IMF5 stored in the database!
# PSSA3_IMF6 stored in the database!
# ENAT3_IMF1 stored in the database!
# ENAT3_IMF2 stored in the database!
# ENAT3_IMF3 stored in the database!
# ENAT3_IMF4 stored in the database!
# ENAT3_IMF5 stored in the database!
# ENAT3_IMF6 stored in the database!
# QUAL3_IMF1 stored in the database!
# QUAL3_IMF2 stored in the database!
# QUAL3_IMF3 stored in the database!
# QUAL3_IMF4 stored in the database!
# QUAL3_IMF5 stored in the database!
# QUAL3_IMF6 stored in the database!
# RADL3_IMF1 stored in the database!
# RADL3_IMF2 stored in the database!
# RADL3_IMF3 stored in the database!
# RADL3_IMF4 stored in the database!
# RADL3_IMF5 stored in the database!
# RADL3_IMF6 stored in the database!
# RADL3_IMF7 stored in the database!
# RAPT4_IMF1 stored in the database!
# RAPT4_IMF2 stored in the database!
# RAPT4_IMF3 stored in the database!
# RAPT4_IMF4 stored in the database!
# RAPT4_IMF5 stored in the database!
# RAPT4_IMF6 stored in the database!
# RENT3_IMF1 stored in the database!
# RENT3_IMF2 stored in the database!
# RENT3_IMF3 stored in the database!
# RENT3_IMF4 stored in the database!
# RENT3_IMF5 stored in the database!
# RENT3_IMF6 stored in the database!
# RENT3_IMF7 stored in the database!
# RSID3_IMF1 stored in the database!
# RSID3_IMF2 stored in the database!
# RSID3_IMF3 stored in the database!
# RSID3_IMF4 stored in the database!
# RSID3_IMF5 stored in the database!
# RSID3_IMF6 stored in the database!
# SANB3_IMF1 stored in the database!
# SANB3_IMF2 stored in the database!
# SANB3_IMF3 stored in the database!
# SANB3_IMF4 stored in the database!
# SANB3_IMF5 stored in the database!
# SANB3_IMF6 stored in the database!
# SANB3_IMF7 stored in the database!
# SBSP3_IMF1 stored in the database!
# SBSP3_IMF2 stored in the database!
# SBSP3_IMF3 stored in the database!
# SBSP3_IMF4 stored in the database!
# SBSP3_IMF5 stored in the database!
# SBSP3_IMF6 stored in the database!
# SBSP3_IMF7 stored in the database!
# SULA11_IMF1 stored in the database!
# SULA11_IMF2 stored in the database!
# SULA11_IMF3 stored in the database!
# SULA11_IMF4 stored in the database!
# SULA11_IMF5 stored in the database!
# SULA11_IMF6 stored in the database!
# SULA11_IMF7 stored in the database!
# TAEE11_IMF1 stored in the database!
# TAEE11_IMF2 stored in the database!
# TAEE11_IMF3 stored in the database!
# TAEE11_IMF4 stored in the database!
# TAEE11_IMF5 stored in the database!
# TAEE11_IMF6 stored in the database!
# TAEE11_IMF7 stored in the database!
# TIMS3_IMF1 stored in the database!
# TIMS3_IMF2 stored in the database!
# TIMS3_IMF3 stored in the database!
# TIMS3_IMF4 stored in the database!
# TIMS3_IMF5 stored in the database!
# TIMS3_IMF6 stored in the database!
# TIMS3_IMF7 stored in the database!
# TOTS3_IMF1 stored in the database!
# TOTS3_IMF2 stored in the database!
# TOTS3_IMF3 stored in the database!
# TOTS3_IMF4 stored in the database!
# TOTS3_IMF5 stored in the database!
# TOTS3_IMF6 stored in the database!
# TOTS3_IMF7 stored in the database!
# UGPA3_IMF1 stored in the database!
# UGPA3_IMF2 stored in the database!
# UGPA3_IMF3 stored in the database!
# UGPA3_IMF4 stored in the database!
# UGPA3_IMF5 stored in the database!
# UGPA3_IMF6 stored in the database!
# UGPA3_IMF7 stored in the database!
# USIM5_IMF1 stored in the database!
# USIM5_IMF2 stored in the database!
# USIM5_IMF3 stored in the database!
# USIM5_IMF4 stored in the database!
# USIM5_IMF5 stored in the database!
# USIM5_IMF6 stored in the database!
# VALE3_IMF1 stored in the database!
# VALE3_IMF2 stored in the database!
# VALE3_IMF3 stored in the database!
# VALE3_IMF4 stored in the database!
# VALE3_IMF5 stored in the database!
# VALE3_IMF6 stored in the database!
# VIVT3_IMF1 stored in the database!
# VIVT3_IMF2 stored in the database!
# VIVT3_IMF3 stored in the database!
# VIVT3_IMF4 stored in the database!
# VIVT3_IMF5 stored in the database!
# VIVT3_IMF6 stored in the database!
# VIVT3_IMF7 stored in the database!
# VLID3_IMF1 stored in the database!
# VLID3_IMF2 stored in the database!
# VLID3_IMF3 stored in the database!
# VLID3_IMF4 stored in the database!
# VLID3_IMF5 stored in the database!
# VLID3_IMF6 stored in the database!
# VVAR11_IMF1 stored in the database!
# VVAR11_IMF2 stored in the database!
# VVAR11_IMF3 stored in the database!
# VVAR11_IMF4 stored in the database!
# VVAR11_IMF5 stored in the database!
# VVAR11_IMF6 stored in the database!
# WEGE3_IMF1 stored in the database!
# WEGE3_IMF2 stored in the database!
# WEGE3_IMF3 stored in the database!
# WEGE3_IMF4 stored in the database!
# WEGE3_IMF5 stored in the database!
# WEGE3_IMF6 stored in the database!
